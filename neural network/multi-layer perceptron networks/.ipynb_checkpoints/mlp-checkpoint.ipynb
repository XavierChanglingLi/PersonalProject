# %% [markdown]
# **Changling Li**
#
# Fall 2020
#
# CS 343: Neural Networks
#
# Project 2: Multi-layer Perceptrons
#
# **Submission reminders:**
#
# - Submit rubric on Google Classroom (one per team)
# - Submit one .zip file per team on Google Classroom. Includes:
#     - All .ipynb notebook files
#     - All .py code files
#     - Data files under 10 MB
# - Did you answer all 9 questions?

# %%
import os
import random
import numpy as np
import matplotlib.pyplot as plt

# for obtaining the STL-dataset
import load_stl10_dataset

# for preprocessing dataset
import preprocess_data

# Set the color style so that Professor Layton can see your plots
plt.style.use(['seaborn-colorblind', 'seaborn-darkgrid'])
# Make the font size larger
plt.rcParams.update({'font.size': 20})

# Turn off scientific notation when printing
np.set_printoptions(suppress=True, precision=3)

# Automatically reload external modules
# %load_ext autoreload
# %autoreload 2

def plot_cross_entropy_loss(loss_history):
    plt.plot(loss_history)
    plt.xlabel('Training iteration')
    plt.ylabel('loss (cross-entropy)')
    plt.show()

# %% [markdown]
# ## Load in data
#
# ### a. STL-10
#
# Run your function to load in the preprocessed STL-10 data in the following split:
#
# - 3500 training samples
# - 500 test samples
# - 500 validation samples
# - 500 samples for development

# %%
x_train, y_train, x_test, y_test, x_val, y_val, x_dev, y_dev = preprocess_data.load_stl10(3500,500,500,500)
# Out:
# Found cached numpy arrays the images and labels. Loading them...
# Images are: (5000, 32, 32, 3)
# Labels are: (5000,)

# %% [markdown]
# ### b. Circle in a square
#
# The circle in a square (CIS) dataset is a simple binary classification dataset that is useful for debugging and visualizing what your MLP is learning. Points with (x, y) coordinates inside a circle have class value of 1, points with coordinates outside the circle have class value of 0. Training on the CIS dataset allows us to answer the question: can the MLP discriminate whether a test point falls inside or outside the circle?
#
# #### Todo
#
# - Download the CIS dataset then run the cell below to load in the CIS train (`cis_train.dat`) and test (`cis_test.dat`) sets as numpy arrays.
# - Below, make a scatterplot showing the test set data. Color-code samples based on their class. If everything goes well, you should see a...solid, filled in circle inside unit square :)
#     - Make the aspect ratio of your x, y plotting axes equal, otherwiwse you might see an ellipse!
#
# In case you're curious about the data format:
# - Like usual, each row is a different sample.
# - The x-coordinate feature is the 1st column
# - The y-coordinate feature is the 2nd column
# - The class label (0 or 1) is in the third column.

# %%
val_size = 20

cis_train_path = os.path.join('data', 'cis', 'cis_train.dat')
cis_test_path = os.path.join('data', 'cis', 'cis_test.dat')

cis_train_all = np.loadtxt(cis_train_path, delimiter='\t')

# shuffle the data
s_inds = np.arange(len(cis_train_all))
np.random.seed(0)
np.random.shuffle(s_inds)

cis_train_all = cis_train_all[s_inds]

cis_train_x = cis_train_all[:, :2]
cis_train_y = cis_train_all[:, 2].astype(int)

cis_val_x = cis_train_x[:val_size]
cis_train_x = cis_train_x[val_size:]
cis_val_y = cis_train_y[:val_size]
cis_train_y = cis_train_y[val_size:]

cis_test_all = np.loadtxt(cis_test_path, delimiter='\t')
cis_test_x = cis_test_all[:, :2]
cis_test_y = cis_test_all[:, 2].astype(int)

print ('CIS Train data shape: ', cis_train_x.shape)
print ('CIS Train labels shape: ', cis_train_y.shape)
print ('CIS Validation data shape: ', cis_val_x.shape)
print ('CIS Validation labels shape: ', cis_val_y.shape)
print ('CIS Test data shape: ', cis_test_x.shape)
print ('CIS Test labels shape: ', cis_test_y.shape)
# Out:
# CIS Train data shape:  (80, 2)
# CIS Train labels shape:  (80,)
# CIS Validation data shape:  (20, 2)
# CIS Validation labels shape:  (20,)
# CIS Test data shape:  (10000, 2)
# CIS Test labels shape:  (10000,)

# %%
# scatter plot here
plt.scatter(cis_test_x[:,0],cis_test_x[:,1],c=cis_test_y)
plt.suptitle("cicle in square")
plt.axis("equal")
plt.show()

# %% [markdown]
# ## Task 3: Implement Multilayer Perceptron (MLP) with softmax activation and cross-entropy loss
#
# Now that we've tested the softmax activation function and cross-entropy loss functions in a single-layer net, let's implement the MLP version.
#
# Much of your work on the single layer net will carry over, so go ahead and copy-paste and modify as needed!
#
# The structure of our MLP will be:
#
# ```
# Input layer (X units) ->
# Hidden layer (Y units) with Rectified Linear activation (ReLu) ->
# Output layer (Z units) with softmax activation
# ```

# %% [markdown]
# ### 3a. Implement the following functions in `mlp.py`
#
# - `initialize_wts`
# - `accuracy`
# - `one_hot`
# - `predict`
# - `forward`
# - `backward`
# - `fit`

# %% [markdown]
# ### 3b. Test key functions with randomly generated data

# %%
from mlp import MLP

# %%
# Create a dummy net for debugging
num_inputs = 3
num_features = 6
num_hidden_units = 7
num_classes = 5

net = MLP(num_features, num_hidden_units, num_classes)

# %%
# Generate random data and classes
np.random.seed(0)
test_x = np.random.normal(loc=0, scale=100, size=(num_inputs, num_features))
test_y = np.random.uniform(low=0, high=num_classes-1, size=(num_inputs,))
test_y = test_y.astype(int)
print(f'Test input shape: {test_x.shape}')
print(f'Test class vector shape: {test_y.shape}')
# Out:
# Test input shape: (3, 6)
# Test class vector shape: (3,)

# %% [markdown]
# #### Test `initialize_wts`

# %%
net.initialize_wts(M=num_features, H=num_hidden_units, C=num_classes, std=0.01)
print(f'y wt shape is {net.y_wts.shape} and should be (6, 7)')
print(f'y bias shape is {net.y_b.shape} and should be (7,)')
print(f'z wt shape is {net.z_wts.shape} and should be (7, 5)')
print(f'z bias shape is {net.z_b.shape} and should be (5,)')

print(f'1st few y wts are\n{net.y_wts[:,0]}\nand should be\n[ 0.018 -0.002  0.004  0.007  0.015  0.002]')
print(f'y bias is\n{net.y_b}\nand should be\n[-0.017  0.02  -0.005 -0.004 -0.013  0.008 -0.016]')
print(f'1st few z wts are\n{net.z_wts[:,0]}\nand should be\n[-0.002 -0.    -0.004  0.002  0.001  0.004  0.001]')
print(f'z bias is\n{net.z_b}\nand should be\n[ 0.015  0.019  0.012 -0.002 -0.011]')
# Out:
# y wt shape is (6, 7) and should be (6, 7)
# y bias shape is (7,) and should be (7,)
# z wt shape is (7, 5) and should be (7, 5)
# z bias shape is (5,) and should be (5,)
# 1st few y wts are
# [ 0.018 -0.002  0.004  0.007  0.015  0.002]
# and should be
# [ 0.018 -0.002  0.004  0.007  0.015  0.002]
# y bias is
# [-0.017  0.02  -0.005 -0.004 -0.013  0.008 -0.016]
# and should be
# [-0.017  0.02  -0.005 -0.004 -0.013  0.008 -0.016]
# 1st few z wts are
# [-0.002 -0.    -0.004  0.002  0.001  0.004  0.001]
# and should be
# [-0.002 -0.    -0.004  0.002  0.001  0.004  0.001]
# z bias is
# [ 0.015  0.019  0.012 -0.002 -0.011]
# and should be
# [ 0.015  0.019  0.012 -0.002 -0.011]

# %% [markdown]
# #### Test the `predict` method

# %%
test_y_pred = net.predict(test_x)
print(f'Predicted classes are {test_y_pred} and should be [3 0 0]')
# Out:
# Predicted classes are [3 0 0] and should be [3 0 0]

# %% [markdown]
# #### Test the `forward` method focusing on`ReLU`(net act of hidden layer `y`)

# %%
_,y_net_act_test,_,_,_ = net.forward(test_x, test_y)

correct_y_act = np.array([[7.643, 4.49 , 0.799, 9.977, 0.   , 0.   , 0.   ],
       [2.353, 2.737, 2.175, 2.547, 0.345, 0.   , 0.   ],
       [3.98 , 2.691, 1.19 , 3.029, 0.   , 0.   , 0.   ]])

print(f'Your y activation is\n{y_net_act_test}')
print(f'The correct y activation (ReLU) is\n{correct_y_act}')
# Out:
# Your y activation is
# [[7.643 4.49  0.799 9.977 0.    0.    0.   ]
#  [2.353 2.737 2.175 2.547 0.345 0.    0.   ]
#  [3.98  2.691 1.19  3.029 0.    0.    0.   ]]
# The correct y activation (ReLU) is
# [[7.643 4.49  0.799 9.977 0.    0.    0.   ]
#  [2.353 2.737 2.175 2.547 0.345 0.    0.   ]
#  [3.98  2.691 1.19  3.029 0.    0.    0.   ]]

# %% [markdown]
# #### Test the `forward` method

# %%
_,_,_,probs,_ = net.forward(test_x, test_y)

correct_probs = np.array([[0.219, 0.2  , 0.191, 0.219, 0.171],
       [0.208, 0.204, 0.201, 0.205, 0.183],
       [0.208, 0.202, 0.202, 0.205, 0.183]])

print(f'Your z activation (class probabilities) is\n{probs}')
print(f'The correct z activation (class probabilities) is\n{correct_probs}')
print(f'The sums across rows (for each data sample) are {np.sum(probs, axis=1)}.')
print(f'  You should know what should be :)')
# Out:
# Your z activation (class probabilities) is
# [[0.219 0.2   0.191 0.219 0.171]
#  [0.208 0.204 0.201 0.205 0.183]
#  [0.208 0.202 0.202 0.205 0.183]]
# The correct z activation (class probabilities) is
# [[0.219 0.2   0.191 0.219 0.171]
#  [0.208 0.204 0.201 0.205 0.183]
#  [0.208 0.202 0.202 0.205 0.183]]
# The sums across rows (for each data sample) are [1. 1. 1.].
#   You should know what should be :)

# %% [markdown]
# #### Test the `forward` method, focusing on loss

# %%
y_in, y_act ,z_in, z_act, loss = net.forward(test_x, test_y)
correct_loss = 1.564402690536365

print(f'Your average loss is\n{loss}')
print(f'The correct average loss is approx\n{correct_loss}')
# Out:
# Your average loss is
# 1.564402690536365
# The correct average loss is approx
# 1.564402690536365

# %% [markdown]
# #### Test the `forward` method, focusing on regularization

# %%
y_in, y_act ,z_in, z_act, loss = net.forward(test_x, test_y, reg=1000)
correct_loss = 5.257207314928798

print(f'Your regularized average loss is\n{loss}')
print(f'The correct regularized average loss is approx\n{correct_loss}')
# Out:
# Your regularized average loss is
# 5.257207314928799
# The correct regularized average loss is approx
# 5.257207314928798

# %% [markdown]
# #### Test the `backward` method

# %%
y_in, y_act ,z_in, z_act, loss = net.forward(test_x, test_y, reg=0.5)
grads = net.backward(test_x, test_y, y_in, y_act ,z_in, z_act, reg=0.5)

print('Your gradient for y_wts is\n', grads[0])
print('Your gradient for y_b is\n', grads[1])
print('Your gradient for z_wts is\n', grads[2])
print('Your gradient for z_b is\n', grads[3])
# Out:
# Your gradient for y_wts is
#  [[-0.476  0.057 -0.458 -0.115  0.03  -0.005  0.005]
#  [-0.002  0.014 -0.046 -0.162  0.004  0.004  0.001]
#  [-0.088  0.038 -0.166 -0.325 -0.001 -0.004 -0.013]
#  [-0.331  0.067 -0.398 -0.332  0.001  0.    -0.001]
#  [-0.318  0.089 -0.465 -0.615 -0.001 -0.01  -0.002]
#  [-0.315 -0.036 -0.036  0.806  0.029 -0.005 -0.007]]
# Your gradient for y_b is
#  [-0.005  0.    -0.004 -0.     0.     0.     0.   ]
# Your gradient for z_wts is
#  [[-2.879  0.933  0.131  0.987  0.816]
#  [-1.69   0.669 -0.261  0.699  0.584]
#  [-0.374  0.278 -0.45   0.284  0.242]
#  [-3.221  1.041  0.154  1.111  0.904]
#  [ 0.024  0.027 -0.091  0.029  0.015]
#  [ 0.002 -0.003 -0.004 -0.003 -0.002]
#  [ 0.    -0.006  0.005  0.002 -0.008]]
# Your gradient for z_b is
#  [-0.455  0.202 -0.135  0.209  0.179]

# %% [markdown]
# The correct gradients are:
#
# `
# Your gradient for y_wts is
#  [[-0.476  0.057 -0.458 -0.115  0.03  -0.005  0.005]
#  [-0.002  0.014 -0.046 -0.162  0.004  0.004  0.001]
#  [-0.088  0.038 -0.166 -0.325 -0.001 -0.004 -0.013]
#  [-0.331  0.067 -0.398 -0.332  0.001  0.    -0.001]
#  [-0.318  0.089 -0.465 -0.615 -0.001 -0.01  -0.002]
#  [-0.315 -0.036 -0.036  0.806  0.029 -0.005 -0.007]]
# Your gradient for y_b is
#  [-0.005  0.    -0.004 -0.     0.     0.     0.   ]
# Your gradient for z_wts is
#  [[-2.879  0.933  0.131  0.987  0.816]
#  [-1.69   0.669 -0.261  0.699  0.584]
#  [-0.374  0.278 -0.45   0.284  0.242]
#  [-3.221  1.041  0.154  1.111  0.904]
#  [ 0.024  0.027 -0.091  0.029  0.015]
#  [ 0.002 -0.003 -0.004 -0.003 -0.002]
#  [ 0.    -0.006  0.005  0.002 -0.008]]
# Your gradient for z_b is
#  [-0.455  0.202 -0.135  0.209  0.179]
# `

# %% [markdown]
# #### Test loss over epoch (1 of 2).
#
# The below code should generate a curve that rapidly drops to 0 (there might be fluctuations and it might not be monotonic and that's ok)
#
# Your `fit` function should show you print-outs showing:
# - Loss and validation accuracy 4 times throughout training.
# - 100% accuracy on validation set after around 5 epochs of training.
# - You are training on 20 epochs.
# - There are 20 iterations.
# - There is 1 iteration per epoch.
#
# Here is an example print-out from `fit`:
#
#     Starting to train network...There will be 20 epochs and 20 iterations total, 1 iter/epoch.
#      Completed Epoch 0/19. Training loss: 3.78. Validation accuracy: 33.33%.
#      Completed Epoch 5/19. Training loss: 0.13. Validation accuracy: 100.00%.
#      Completed Epoch 10/19. Training loss: 0.22. Validation accuracy: 100.00%.
#      Completed Epoch 15/19. Training loss: 0.15. Validation accuracy: 100.00%.
#     Finished training!

# %%
net = MLP(num_features, num_hidden_units, num_classes)
loss_hist, acc_train, acc_valid = net.fit(test_x, test_y, test_x, test_y, reg=0, print_every=5, lr=0.001, mini_batch_sz=3, n_epochs=20)

print('\nLengths of each output list:')
print(f'{len(loss_hist)}, {len(acc_train)}, {len(acc_valid)}')
print('Each should be 20.')

plot_cross_entropy_loss(loss_hist)
# Out:
# Completed Epoch 0 / 20 . Training loss:  3.7791838687375567 . Validation accuracy: 0.3333333333333333
# Completed Epoch 5 / 20 . Training loss:  0.13201974815508663 . Validation accuracy: 1.0
# Completed Epoch 10 / 20 . Training loss:  0.21819365104176167 . Validation accuracy: 1.0
# Completed Epoch 15 / 20 . Training loss:  0.1545376135701361 . Validation accuracy: 1.0
# Finished training!
#
# Lengths of each output list:
# 20, 20, 20
# Each should be 20.

# %% [markdown]
# #### Test loss over epoch (2 of 2).
#
# The below curve should be more jagged that above, but still converge to 0 loss.
#
# Your `fit` function should print out:
# - Loss and validation accuracy 5 times throughout training.
# - 100% accuracy on validation set after around 4 epochs of training.
# - You are training on 10 epochs.
# - There are 30 iterations.
# - There are 3 iterations per epoch.

# %%
net = MLP(num_features, num_hidden_units, num_classes)
loss_hist, acc_train, acc_valid = net.fit(test_x, test_y, test_x, test_y, reg=0, print_every=2, lr=0.001, mini_batch_sz=1, n_epochs=10)

print('\nLengths of each output list:')
print(f'{len(loss_hist)}, {len(acc_train)}, {len(acc_valid)}')
print('The lengths should be 30, 10, 10.')

plot_cross_entropy_loss(loss_hist)
# Out:
# Completed Epoch 0 / 10 . Training loss:  3.779183868737557 . Validation accuracy: 0.3333333333333333
# Completed Epoch 2 / 10 . Training loss:  1.3963673335241478 . Validation accuracy: 0.6666666666666666
# Completed Epoch 4 / 10 . Training loss:  0.03175248381029712 . Validation accuracy: 1.0
# Completed Epoch 6 / 10 . Training loss:  2.7582183577383763e-07 . Validation accuracy: 1.0
# Completed Epoch 8 / 10 . Training loss:  1.1026015930855305e-07 . Validation accuracy: 1.0
# Finished training!
#
# Lengths of each output list:
# 30, 10, 10
# The lengths should be 30, 10, 10.

# %% [markdown]
# ### 3c. Test MLP with Circle in Square dataset

# %% [markdown]
# Before you run your MLP on the STL-10 dataset, test it out on the simpler CIS dataset.
#
# In cells below:
# - Train an MLP using the CIS training and validation sets. Configure the MLP with the following non-default hyperparameters:
#     - 50 hidden units
#     - Learning rate of 0.5
#     - Mini-batch size of 80
#     - 1000 epochs
# - Plot the loss over training iterations. You should see:
#     - A nice drop and plateau in mini-batch training loss.
#     - Accuracy on the validation set reach ~90%.
# - Create a scatterplot of the MLP predictions on the CIS test set. Color-code each sample by its class. Make sure your axis aspect ratios are equal.

# %%
cis_net = MLP(2, 50, 2)
cis_loss_hist, cis_acc_train, cis_acc_valid = cis_net.fit(cis_train_x, cis_train_y, cis_val_x, cis_val_y, reg=0, print_every=100, lr=0.5, mini_batch_sz=80, n_epochs=1000)
plot_cross_entropy_loss(cis_loss_hist)
# Out:
# Completed Epoch 0 / 1000 . Training loss:  0.7003411416478323 . Validation accuracy: 0.6
# Completed Epoch 100 / 1000 . Training loss:  0.6433178281432161 . Validation accuracy: 0.65
# Completed Epoch 200 / 1000 . Training loss:  0.5140565566372783 . Validation accuracy: 0.8
# Completed Epoch 300 / 1000 . Training loss:  0.42549271000058503 . Validation accuracy: 0.65
# Completed Epoch 400 / 1000 . Training loss:  0.3796234462841133 . Validation accuracy: 0.75
# Completed Epoch 500 / 1000 . Training loss:  0.18259858079882463 . Validation accuracy: 0.85
# Completed Epoch 600 / 1000 . Training loss:  0.11620957780953756 . Validation accuracy: 0.9
# Completed Epoch 700 / 1000 . Training loss:  0.10536716254890013 . Validation accuracy: 0.85
# Completed Epoch 800 / 1000 . Training loss:  0.06519329667719818 . Validation accuracy: 0.9
# Completed Epoch 900 / 1000 . Training loss:  0.056818731981259495 . Validation accuracy: 0.9
# Finished training!

# %%
y_predict = cis_net.predict(cis_test_x)
plt.scatter(cis_test_x[:,0],cis_test_x[:,1],c=y_predict)
plt.suptitle("cicle in square")
plt.axis("equal")
plt.show()

# %% [markdown]
# **Question 5**: How do you interpret the circle-in-square scatterplot? Is the MLP doing a good job?
#
# **Question 6**: Play with
# - number of hidden units
# - number of epochs
# - batch size
#
# How does each parameter affect the results?
#
# **Question 7**: Do you think the single-layer net (with softmax) can handle the CIS dataset? Why or why not? (You're invited to try it, maybe as an extension :)

# %% [markdown]
# **Answer 5**: The circle-in-square scatterplot clarifies an area of circle. The points inside of that area is inside of the circle and the points outside of that area but within a unit is a square. The scatterplots classifies the points inside of a unit square. The MLP did a pretty good job as the points that are predicted as the circle form a rough circle shape. However, it can be improved.
#
# **Answer 6**: For number of hidden units, the more hidden units, the more accurate the prediction is. For the number of epochs, within a range, when the number of epochs increases, the accuracy increases and the loss decreases. When it reaches a value, the accuracy stops increasing. For the batch size, when the batch size is really small, the printed out accuracy can reach to 0.95. However, the loss graph shows that it is unstable as the loss varies a lot. When the batch size increased, the accuracy cannot reach as high but the loss is more stable over the trainning epochs.
#
# **Answer 7**: A single-layer net with softmax cannot handle the CIS dataset as the classification as shown in the graph is not linear. Without non-linear function, the result won't be non-linear.

# %% [markdown]
# ### 3d. Test on STL-10 dataset, plot performance
#
# Train an MLP on the STL-10 training set with the following non-default hyperparameters:
# - 50 hidden units
# - Learning rate of 0.1
# - Regularization strength of 0.001
# - Mini-batch size of 500
# - 100 epochs
#
# Make two plots:
# - Plot the training loss (like usual).
# - Plot the training and validation set accuracies (2 curves in one plot — include a legend, title, axis labels, etc.).

# %%
stl_net = MLP(3072, 50, 10)
loss_hist, acc_train, acc_valid = stl_net.fit(x_train, y_train, x_val , y_val, reg=0.001, print_every=5, lr=0.1, mini_batch_sz=500, n_epochs=100)
# Out:
# Completed Epoch 0 / 100 . Training loss:  3.2191588942838543 . Validation accuracy: 0.084
# Completed Epoch 5 / 100 . Training loss:  2.670734019241916 . Validation accuracy: 0.248
# Completed Epoch 10 / 100 . Training loss:  2.5857704582179797 . Validation accuracy: 0.302
# Completed Epoch 15 / 100 . Training loss:  2.4916066057735815 . Validation accuracy: 0.316
# Completed Epoch 20 / 100 . Training loss:  2.455731808206888 . Validation accuracy: 0.338
# Completed Epoch 25 / 100 . Training loss:  2.3922241847326378 . Validation accuracy: 0.344
# Completed Epoch 30 / 100 . Training loss:  2.376455441443211 . Validation accuracy: 0.35
# Completed Epoch 35 / 100 . Training loss:  2.2765798924210805 . Validation accuracy: 0.36
# Completed Epoch 40 / 100 . Training loss:  2.225559839513992 . Validation accuracy: 0.354
# Completed Epoch 45 / 100 . Training loss:  2.22416252748803 . Validation accuracy: 0.374
# Completed Epoch 50 / 100 . Training loss:  2.1769361214679224 . Validation accuracy: 0.378
# Completed Epoch 55 / 100 . Training loss:  2.1832004979306485 . Validation accuracy: 0.39
# Completed Epoch 60 / 100 . Training loss:  2.200716979707348 . Validation accuracy: 0.376
# Completed Epoch 65 / 100 . Training loss:  2.0306963347121325 . Validation accuracy: 0.386
# Completed Epoch 70 / 100 . Training loss:  2.0637360111444667 . Validation accuracy: 0.38
# Completed Epoch 75 / 100 . Training loss:  2.0169812564870275 . Validation accuracy: 0.374
# Completed Epoch 80 / 100 . Training loss:  1.9578479253621306 . Validation accuracy: 0.38
# Completed Epoch 85 / 100 . Training loss:  1.8766970308660769 . Validation accuracy: 0.398
# Completed Epoch 90 / 100 . Training loss:  1.947375901612416 . Validation accuracy: 0.396
# Completed Epoch 95 / 100 . Training loss:  1.8438365756255581 . Validation accuracy: 0.39
# Finished training!

# %%
plot_cross_entropy_loss(loss_hist)

plt.plot(acc_train, label = 'train')
plt.plot(acc_valid, label = 'valid')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.show()

# %% [markdown]
# **Question 7**: What do the above loss and training and validation accuracy curves suggest about the quality of the hyperparameters used during training?

# %% [markdown]
# The accuracy of validation is much smaller than the training. This suggests that there might be overfitting. We might want to change the regularization parameter and others to find the best hyperparameters.

# %% [markdown]
# ### 3e. Optimize on STL-10 dataset with random search
#
# To optimize your MLP hyperparameters on STL-10, try a **random search** rather than a grid search. This means that instead of defining preset *values* that each hyperparameter takes on, define *ranges* (min and max values).
#
# Run your search for some $T$ iterations. On each iteration, randomly assign values to each hyperparameter within their valid ranges.
#
# Just like grid search, print out the accuracy and parameter values every time a bout of training yields the best accuracy on the STL-10 validation set. That way, if you need to stop the search prematurely, you know the current best parameter combination.
#
# Consider the following hyperparameters:
# - learning rate
# - regularization strength
# - number of hidden units
# - mini-batch size
#
# **Important note:** Like usual, I am not grading based on your performance numbers. I want to see that you successfully implemented the random search to find progressively better hyperparameters on STL-10.
#
# **Tip:** Just like with grid search, if you find a cluster of parameters that seems promising, you can revise your search to hone in on that smaller range.

# %%
# hidden_unit_range = random.randint(100, 512)
best_loss = 99999
best_acc = 0
for _ in range(50):
    lr_range = random.uniform(0.001, 1)
    reg_range = random.uniform(0.001, 1) 
    batch_range = random.randint(1, 5000)
    hidden_unit_range = random.randint(100, 512)
    best_net = MLP(3072, hidden_unit_range, 10)
    loss_hist, acc_train, acc_valid = stl_net.fit(x_train, y_train, x_val , y_val, reg=reg_range, verbose=0, lr=lr_range, mini_batch_sz=batch_range, n_epochs=30)
    if len(loss_hist) > 0 and loss_hist[-1] < best_loss:
        best_loss = loss_hist[-1]
        print("best loss", best_loss, "lr_range", lr_range, "reg_range", reg_range, 
              "batch_range", batch_range, "hidden_unit_range", hidden_unit_range)
    if len(acc_valid) > 0 and acc_valid[-1] > best_acc:
        best_acc = acc_valid[-1]
        print("best acc", best_acc, "lr_range", lr_range, "reg_range", reg_range, 
              "batch_range", batch_range, "hidden_unit_range", hidden_unit_range)
        
print("\n Finished searching!")
# Out:
# Finished training!
# best loss 1.8969631405989695 lr_range 0.21586330236385956 reg_range 0.06102963553772385 batch_range 253 hidden_unit_range 456
# best acc 0.342 lr_range 0.21586330236385956 reg_range 0.06102963553772385 batch_range 253 hidden_unit_range 456
# Finished training!
# Finished training!
# Finished training!
# Finished training!
# Finished training!
# Finished training!
# Finished training!
# Finished training!
# Finished training!
# Finished training!
# Finished training!
# Finished training!
# Finished training!
# Finished training!
# Finished training!
# Finished training!
# Finished training!
# Finished training!
# Finished training!
# Finished training!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-36-2b4c839017f2> in <module>
#       8     hidden_unit_range = random.randint(100, 512)
#       9     best_net = MLP(3072, hidden_unit_range, 10)
# ---> 10     loss_hist, acc_train, acc_valid = stl_net.fit(x_train, y_train, x_val , y_val, reg=reg_range, verbose=0, lr=lr_range, mini_batch_sz=batch_range, n_epochs=30)
#      11     if len(loss_hist) > 0 and loss_hist[-1] < best_loss:
#      12         best_loss = loss_hist[-1]
#
# ~/Desktop/CS/cs343/project/project2/mlp.py in fit(self, features, y, x_validation, y_validation, resume_training, n_epochs, lr, mini_batch_sz, reg, verbose, print_every)
#     319
#     320             #forward prop
# --> 321             y_net_in, y_net_act, z_net_in, z_net_act, loss = self.forward(mini_batch, mini_batch_true_class,reg)
#     322             loss_history.append(loss)
#     323             #backprop
#
# ~/Desktop/CS/cs343/project/project2/mlp.py in forward(self, features, y, reg)
#     170
#     171         #ReLu for the hidden layer netAct
# --> 172         y_net_in = features@self.y_wts + self.y_b
#     173         y_net_act = y_net_in
#     174         y_net_act[y_net_in<0]=0
#
# KeyboardInterrupt:

# %% [markdown]
# ### 3f. Plot STL-10 results with best hyperparameters
#
# Train an MLP with the best hyperparameters that you found from your parameter search and create two plots:
# - Training STL-10 loss curve
# - Training and validation set STL-10 accuracy curves

# %%
bestNet = MLP(3072, 456, 10)
loss_hist, acc_train, acc_valid = bestNet.fit(x_train, y_train, x_val , y_val, reg=0.061, print_every=5, lr=0.2159, mini_batch_sz=253, n_epochs=200)
# Out:
# Completed Epoch 0 / 200 . Training loss:  432.080318121036 . Validation accuracy: 0.166
# Completed Epoch 5 / 200 . Training loss:  78.11641185085834 . Validation accuracy: 0.376
# Completed Epoch 10 / 200 . Training loss:  15.47227483001514 . Validation accuracy: 0.392
# Completed Epoch 15 / 200 . Training loss:  4.346810309075014 . Validation accuracy: 0.404
# Completed Epoch 20 / 200 . Training loss:  2.352215210383174 . Validation accuracy: 0.364
# Completed Epoch 25 / 200 . Training loss:  2.032536632574142 . Validation accuracy: 0.374
# Completed Epoch 30 / 200 . Training loss:  2.014932879765766 . Validation accuracy: 0.39
# Completed Epoch 35 / 200 . Training loss:  1.9055060349993045 . Validation accuracy: 0.404
# Completed Epoch 40 / 200 . Training loss:  1.9431171820841002 . Validation accuracy: 0.394
# Completed Epoch 45 / 200 . Training loss:  1.8718588651489485 . Validation accuracy: 0.378
# Completed Epoch 50 / 200 . Training loss:  1.8645110743739226 . Validation accuracy: 0.38
# Completed Epoch 55 / 200 . Training loss:  1.8430674777423952 . Validation accuracy: 0.374
# Completed Epoch 60 / 200 . Training loss:  1.8910576861625392 . Validation accuracy: 0.378
# Completed Epoch 65 / 200 . Training loss:  1.9329566762252994 . Validation accuracy: 0.38
# Completed Epoch 70 / 200 . Training loss:  1.9220297069219878 . Validation accuracy: 0.364
# Completed Epoch 75 / 200 . Training loss:  1.958056478663846 . Validation accuracy: 0.366
# Completed Epoch 80 / 200 . Training loss:  1.9518840378978417 . Validation accuracy: 0.394
# Completed Epoch 85 / 200 . Training loss:  1.9260084682580803 . Validation accuracy: 0.384
# Completed Epoch 90 / 200 . Training loss:  1.9590909854459946 . Validation accuracy: 0.386
# Completed Epoch 95 / 200 . Training loss:  1.8513555555974923 . Validation accuracy: 0.394
# Completed Epoch 100 / 200 . Training loss:  1.9476453942432665 . Validation accuracy: 0.402
# Completed Epoch 105 / 200 . Training loss:  1.8679528678645358 . Validation accuracy: 0.398
# Completed Epoch 110 / 200 . Training loss:  1.8824268544186036 . Validation accuracy: 0.36
# Completed Epoch 115 / 200 . Training loss:  1.892211889941417 . Validation accuracy: 0.4
# Completed Epoch 120 / 200 . Training loss:  1.868928217661528 . Validation accuracy: 0.368
# Completed Epoch 125 / 200 . Training loss:  1.8538750923782445 . Validation accuracy: 0.394
# Completed Epoch 130 / 200 . Training loss:  1.9256634871690415 . Validation accuracy: 0.376
# Completed Epoch 135 / 200 . Training loss:  1.8827591397085812 . Validation accuracy: 0.392
# Completed Epoch 140 / 200 . Training loss:  1.9246905141054669 . Validation accuracy: 0.378
# Completed Epoch 145 / 200 . Training loss:  1.8764108242646031 . Validation accuracy: 0.372
# Completed Epoch 150 / 200 . Training loss:  1.8981932903068117 . Validation accuracy: 0.386
# Completed Epoch 155 / 200 . Training loss:  1.9587025402040839 . Validation accuracy: 0.37
# Completed Epoch 160 / 200 . Training loss:  1.861232090043191 . Validation accuracy: 0.366
# Completed Epoch 165 / 200 . Training loss:  1.8929350446581865 . Validation accuracy: 0.374
# Completed Epoch 170 / 200 . Training loss:  1.8882798929397362 . Validation accuracy: 0.41
# Completed Epoch 175 / 200 . Training loss:  1.9323516218636678 . Validation accuracy: 0.394
# Completed Epoch 180 / 200 . Training loss:  1.8777814403204158 . Validation accuracy: 0.372
# Completed Epoch 185 / 200 . Training loss:  1.9611939434187187 . Validation accuracy: 0.412
# Completed Epoch 190 / 200 . Training loss:  1.830567038833547 . Validation accuracy: 0.41
# Completed Epoch 195 / 200 . Training loss:  1.9050890436976726 . Validation accuracy: 0.394
# Finished training!

# %%
plot_cross_entropy_loss(loss_hist)

plt.plot(acc_train, label = 'train')
plt.plot(acc_valid, label = 'valid')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.show()

# %%
y_predict = bestNet.predict(x_test)
accuracy = bestNet.accuracy(y_test,y_predict)
print(accuracy)
# Out:
# 0.346

# %% [markdown]
# **Question 8**: Use your best trained network to compute the accuracy on the test set after 200 epochs. What accuracy do you get?
#
# **Question 9:** Why would you use random search over grid search when optimizing parameters on a dataset?

# %% [markdown]
# **Answer 8**: The accuracy I got is 0.346
#
# **Answer 9:** Random search can avoid the situation when using grid search that the global or local minimum are skipped due to the set step of the hyperparatmeter during search.

# %% [markdown]
# ### 3g. Visualize learned weights
#
# Run the `plot_weights` function to generate a grid visualization of them.
#
# You should see structure in the weights if your network is performing well. If you have a large number of hidden units, some may not be "used" so a subset of the weights may resemble "noise".

# %%
best_y_wts = bestNet.get_y_wts()
best_y_wts = best_y_wts.reshape(32, 32, 3, -1).transpose(3, 0, 1, 2)

# %%
def plot_weights(wts, maxRows=25, verbose=0):
    # limit height of figure by number of neurons
    grid_sz = int(maxRows)
    grid_sz = np.minimum(grid_sz, int(np.sqrt(len(wts))))

    if verbose > 0:
        print(f'Showing {grid_sz} rows')
    
    plt.figure(figsize=(20,20))
    for x in range(grid_sz):
        for y in range(grid_sz):
            lin_ind = np.ravel_multi_index((x, y), dims=(grid_sz, grid_sz))
            plt.subplot(grid_sz, grid_sz, lin_ind+1)
            currImg = wts[lin_ind]
            low, high = np.min(currImg), np.max(currImg)
            currImg = 255*(currImg - low) / (high - low)
            currImg = currImg.astype('uint8')
            plt.imshow(currImg)
            plt.gca().axis('off')
    plt.show()

# %%
plot_weights(best_y_wts, verbose=1)
# Out:
# Showing 21 rows

# %% [markdown]
# ## Extensions
#
# **Reminder**: Please do not integrate extensions into your base project so that it changes the expected behavior of core functions. It is better to duplicate the base project and add features from there.
#
# 1) Analyze the differences between training when sampling with replacement (i.e. not every input sample is usually processed on an epoch) and sampling without replacement (e.g. time, accuracy, loss, etc).
#
# 2) Investigate how the single layer softmax network does with the CIS dataset. Explain and provide plots showing your results.
#
# 3) If you have time to spare (or want to throw more computing power at the STL-10 dataset), process through the SLP and MLP and tune hyperparameters with the dataset at its original resolution (96x96 images). Show images of your learned weights. Can you find a training sweet spot where the learned weight visualizations look particularly cool?
#
# 4) Implement a multi-class sigmoid classifer. I suggest creating another subclass of `SoftmaxLayer` and/or `MLP`. Compare and contrast results achieved by the softmax network.
#
# 5) Explore alternative MLP architectures and compare/constrast results and performance with the ones used in the base project. For example, replace hidden layer activation function with sigmoid, add one or more additional hidden layers, etc.
#
# 6) Explore the effects of batch gradient descent, stochastic gradient descent, and mini-batch gradient descent. Make plots and interpret your results.
#
# 7) Obtain, preprocess, train, and evaluate the performance of `SoftmaxLayer` and/or `MLP` on another dataset with comparable types of image features. MNIST is a good one.
#
# 8) Make a fancy coarse-to-fine grid search that automatically "zooms in" on the best hyperparameter combination ranges several times.

# %% [markdown]
# **Extension1**: For the first extension, I investigate how the single layer softmax network does with the CIS dataset to explore the importance of including one non-linear activation function in the network. I decided to use the softmax_layer program that I implemented for the first part of the project. Firstly, I train the network on the dataset and then I use the predict and accuracy function to predict the result on the test dataset. Then plot the result out to see how the prediction looks like and use it as a reference to judge the performance.

# %%
from softmax_layer import SoftmaxLayer
soft_cis_net = SoftmaxLayer(2)
loss_history = soft_cis_net.fit(cis_train_x,cis_train_y, n_epochs = 1000)
y_pred = soft_cis_net.predict(cis_test_x)
accuracy = soft_cis_net.accuracy(cis_test_y,y_pred)
plt.scatter(cis_test_x[:,0],cis_test_x[:,1],c=y_pred)
plt.suptitle("cicle in square")
plt.axis("equal")
plt.show()
print("The accuracy is", accuracy)
# Out:
# Finished training!
# The accuracy is 0.5652

# %% [markdown]
# The accuracy is 0.5652. From the graph we can tell that the circle cannot be identified. There is a straight line on the unit square separating the square into two classes. The straight line indicates that the prediction is linear. This shows that when there is only linear activation function, the prediction won't work for non-linear results. Only when non-linear layer is included, can the network predict the results more correctly on a non-linear classification.

# %% [markdown]
# **Extension2**: For the Second extension, I attempt to make a fancy coarse-to-fine grid search where the user can decide how many times of zooms in on the best hyperparamter combination ranges. To achieve this, I used the grid search function that I created for the first part of the project where the fucntion takes in the bounds for learning rate, batch size and regularization. To let the user decide how many times of searching, I also add another parameter search_t. In this function, it will decrement the search time by 1 for every full run of searching. In the while loop, it will search all combinations of the three parameters within the range and then find the best combination. Then the best combination is used to find new ranges for each hyperparameter. To test it, I ran this search with given range. As this takes a long time, I did not get to finish test this. For feature exploration, I will finish running the test and check whether it works properly. However, from the current output, I think it works fine.

# %%
def grid_search(lr_bound, batch_size_bound, regularization_bound, search_t):
#the first number is the lower bound and the second number is the upper bound
    
    lr_list = np.arange(lr_bound[0], lr_bound[1], (lr_bound[1]-lr_bound[0])/10)
    batch_list = np.arange(batch_size_bound[0],batch_size_bound[1],int((batch_size_bound[1]-batch_size_bound[0])/10))
    regularization_list = np.arange(regularization_bound[0],regularization_bound[1],(regularization_bound[1]-regularization_bound[0])/10)
    while(search_t>0):
        his_accuracy_test = []
        his_accuracy_valid = []
        combination = dict()
        for lr in lr_list:
            for batch in batch_list:
                for reg in regularization_list:
                    softmaxNet = SoftmaxLayer(10)
                    loss_history = softmaxNet.fit(x_test, y_test, n_epochs=100, lr=lr, mini_batch_sz=batch, reg=reg)
                    y_predict_test = softmaxNet.predict(x_test)
                    his_accuracy_test.append(softmaxNet.accuracy(y_test,y_predict_test))
                    y_predict_valid = softmaxNet.predict(x_val)
                    his_accuracy_valid.append(softmaxNet.accuracy(y_val,y_predict_valid))
                    combination[softmaxNet.accuracy(y_val,y_predict_valid)] = [lr, batch, reg]
        lr_best = combination.get(max(his_accuracy_valid))[0]
        batch_best = combination.get(max(his_accuracy_valid))[1]
        reg_best = combination.get(max(his_accuracy_valid))[2]
        lr_list = np.arange(lr_best-lr_best/10, lr_best+lr_best/10, (lr_best+lr_best/5)/10)
        batch_list = np.arange(int(batch_list-batch_list/10), int(batch_list+batch_list/10), int((batch_list+batch_list/5)/10))
        regularization_list = np.arange(regularization_list-regularization_list/10, regularization_list+regularization_list/10, (regularization_list+regularization_list/5)/10)
        search_t -=1
#         print(his_accuracy_test)
#         print(his_accuracy_valid)
        print(combination.get(max(his_accuracy_valid)))
    return combination.get(max(his_accuracy_valid))

# %%
learning_rate, regularization, batch_size = grid_search([0.00005,0.00015],[50,550],[0,1],3)
print(learning_rate, regularization, batch_size)
# Out:
# Completed iter 0 / 1000 . Training loss:  2.3080049027783627 .
# Completed iter 100 / 1000 . Training loss:  2.29432730092912 .
# Completed iter 200 / 1000 . Training loss:  2.300249751096812 .
# Completed iter 300 / 1000 . Training loss:  2.3175630828645937 .
# Completed iter 400 / 1000 . Training loss:  2.306849909863504 .
# Completed iter 500 / 1000 . Training loss:  2.3048834911611107 .
# Completed iter 600 / 1000 . Training loss:  2.2962909520982078 .
# Completed iter 700 / 1000 . Training loss:  2.232349057582697 .
# Completed iter 800 / 1000 . Training loss:  2.273101472657375 .
# Completed iter 900 / 1000 . Training loss:  2.2543076850294574 .
# Finished training!
# Completed iter 0 / 1000 . Training loss:  2.4367713001431768 .
# Completed iter 100 / 1000 . Training loss:  2.4779173060684183 .
# Completed iter 200 / 1000 . Training loss:  2.4318531169825053 .
# Completed iter 300 / 1000 . Training loss:  2.43739612692769 .
# Completed iter 400 / 1000 . Training loss:  2.453321666234443 .
# Completed iter 500 / 1000 . Training loss:  2.461362593795947 .
# Completed iter 600 / 1000 . Training loss:  2.4035567197541066 .
# Completed iter 700 / 1000 . Training loss:  2.4088944042513183 .
# Completed iter 800 / 1000 . Training loss:  2.4236669130257678 .
# Completed iter 900 / 1000 . Training loss:  2.3824628886625407 .
# Finished training!
# Completed iter 0 / 1000 . Training loss:  2.6117334769843343 .
# Completed iter 100 / 1000 . Training loss:  2.625777072386785 .
# Completed iter 200 / 1000 . Training loss:  2.6004430067030495 .
# Completed iter 300 / 1000 . Training loss:  2.6283726621597108 .
# Completed iter 400 / 1000 . Training loss:  2.5836928390823837 .
# Completed iter 500 / 1000 . Training loss:  2.579918760078104 .
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-70-f82b1348c786> in <module>
# ----> 1 learning_rate, regularization, batch_size = grid_search([0.00005,0.00015],[50,550],[0,1],3)
#       2 print(learning_rate, regularization, batch_size)
#
# <ipython-input-69-00af812fbb51> in grid_search(lr_bound, batch_size_bound, regularization_bound, search_t)
#      13                 for reg in regularization_list:
#      14                     softmaxNet = SoftmaxLayer(10)
# ---> 15                     loss_history = softmaxNet.fit(x_test, y_test, n_epochs=100, lr=lr, mini_batch_sz=batch, reg=reg)
#      16                     y_predict_test = softmaxNet.predict(x_test)
#      17                     his_accuracy_test.append(softmaxNet.accuracy(y_test,y_predict_test))
#
# ~/Desktop/CS/cs343/project/project2/softmax_layer.py in fit(self, features, y, n_epochs, lr, mini_batch_sz, reg, verbose)
#     165
#     166             # update the bias and the weights
# --> 167             grad_wts, grad_bias = self.gradient(mini_batch, net_act, mini_batch_one_hot, reg)
#     168
#     169             self.b = self.b - lr * grad_bias
#
# ~/Desktop/CS/cs343/project/project2/softmax_layer.py in gradient(self, features, net_act, y, reg)
#     273         num_inputs = len(features)
#     274
# --> 275         grad_wts =(features.T @ (net_act - y))/num_inputs +reg*self.wts
#     276         grad_b = np.sum((net_act-y),axis=0)/num_inputs
#     277         return grad_wts, grad_b
#
# KeyboardInterrupt:
